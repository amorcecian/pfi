# %%
import pandas as pd
import numpy as np
from geopy.distance import distance
centroids_df = pd.read_csv('stations_centroids.csv', sep=';', encoding='cp1250')

# %%
float_values = ['long', 'lat', 'lat_centroide', 'long_centroide']
for float_value in float_values:
    centroids_df[float_value] = centroids_df[float_value].apply(lambda x: float(x.replace(',', '.')))
centroids_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 10 columns):
# long              199 non-null float64
# lat               199 non-null float64
# nombre            199 non-null object
# domicilio         199 non-null object
# nro_est           199 non-null int64
# dire_norm         199 non-null object
# capacidad         199 non-null int64
# cluster           199 non-null int64
# lat_centroide     199 non-null float64
# long_centroide    199 non-null float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 15.7+ KB

# %%
centroids_df_original = centroids_df.copy()
centroids_df.sort_values('cluster').head()
# Out:
#           long        lat                 nombre  \
# 99  -58.442423 -34.589049               Fitz Roy
# 156 -58.445099 -34.592839             Villarroel
# 125 -58.452927 -34.592212  Santos Dumont y Otero
# 102 -58.455062 -34.587548       Federico Lacroze
# 100 -58.445987 -34.586440                 Roseti
#
#                                  domicilio  nro_est              dire_norm  \
# 99                  Fitz Roy 1092 y Loyola      101          1092 FITZ ROY
# 156                  Villarroel y Humboldt      158  VILLARROEL y HUMBOLDT
# 125             Santos Dumont 4380 y Otero      127     4380 DUMONT SANTOS
# 102  Av Corrientes 6800 y Federico Lacroze      104     6900 CORRIENTES AV
# 100                 Roseti 50 y Av Dorrego      102              50 ROSETI
#
#      capacidad  cluster  lat_centroide  long_centroide
# 99          12        0     -34.589985       -58.44849
# 156         12        0     -34.589985       -58.44849
# 125         10        0     -34.589985       -58.44849
# 102         20        0     -34.589985       -58.44849
# 100         12        0     -34.589985       -58.44849

# %%
def euclidean_distance(x):
    return np.sqrt((x['lat'] - x['lat_centroide']) ** 2 + (x['long'] - x['long_centroide']) ** 2)

centroids_df['radius'] = centroids_df.apply(euclidean_distance, axis=1)
centroids_df.head()
# Out:
#         long        lat               nombre  \
# 0 -58.392452 -34.583133  Facultad de Derecho
# 1 -58.374822 -34.592589               Retiro
# 2 -58.368918 -34.611242               Aduana
# 3 -58.368950 -34.601721           Plaza Roma
# 4 -58.420997 -34.580127         Plaza Italia
#
#                                       domicilio  nro_est  \
# 0  Av. Pres.Figueroa Alcorta y  Juan A.Bibiloni        1
# 1   Av. Dr.Jose Ramos Mejia y Del Libertador Av        2
# 2                 Av. Ing.Huergo y Av. Belgrano        3
# 3                            Lavalle y Bouchard        4
# 4                  Av. Santa Fe y Av. Sarmiento        5
#
#                                            dire_norm  capacidad  cluster  \
# 0    FIGUEROA ALCORTA, PRES. AV. y BIBILONI, JUAN A.         20        1
# 1  DEL LIBERTADOR AV. y RAMOS MEJIA, JOSE MARIA, ...         12       18
# 2                    HUERGO, ING. AV. y BELGRANO AV.         12       14
# 3                                 LAVALLE y BOUCHARD         12        5
# 4      SARMIENTO AV. y CALZADA CIRCULAR PLAZA ITALIA         42       11
#
#    lat_centroide  long_centroide  euclidean_distance
# 0     -34.588454      -58.393190            0.005372
# 1     -34.594475      -58.376283            0.002386
# 2     -34.614912      -58.365744            0.004852
# 3     -34.603205      -58.370342            0.002035
# 4     -34.574162      -58.416990            0.007186

# %%
def geodesic_distance(x):
    station_location = (x['lat'],x['long'])
    centroid_location = (x['lat_centroide'],x['long_centroide'])
    return distance(station_location, centroid_location).km
    #return np.sqrt((x['lat'] - x['lat_centroide']) ** 2 + (x['long'] - x['long_centroide']) ** 2)

centroids_df['radius'] = centroids_df.apply(geodesic_distance, axis=1)
centroids_df.head()
# Out:
#         long        lat               nombre  \
# 0 -58.392452 -34.583133  Facultad de Derecho
# 1 -58.374822 -34.592589               Retiro
# 2 -58.368918 -34.611242               Aduana
# 3 -58.368950 -34.601721           Plaza Roma
# 4 -58.420997 -34.580127         Plaza Italia
#
#                                       domicilio  nro_est  \
# 0  Av. Pres.Figueroa Alcorta y  Juan A.Bibiloni        1
# 1   Av. Dr.Jose Ramos Mejia y Del Libertador Av        2
# 2                 Av. Ing.Huergo y Av. Belgrano        3
# 3                            Lavalle y Bouchard        4
# 4                  Av. Santa Fe y Av. Sarmiento        5
#
#                                            dire_norm  capacidad  cluster  \
# 0    FIGUEROA ALCORTA, PRES. AV. y BIBILONI, JUAN A.         20        1
# 1  DEL LIBERTADOR AV. y RAMOS MEJIA, JOSE MARIA, ...         12       18
# 2                    HUERGO, ING. AV. y BELGRANO AV.         12       14
# 3                                 LAVALLE y BOUCHARD         12        5
# 4      SARMIENTO AV. y CALZADA CIRCULAR PLAZA ITALIA         42       11
#
#    lat_centroide  long_centroide  geodesic_distance
# 0     -34.588454      -58.393190           0.594104
# 1     -34.594475      -58.376283           0.248547
# 2     -34.614912      -58.365744           0.500435
# 3     -34.603205      -58.370342           0.208355
# 4     -34.574162      -58.416990           0.757000

# %%
centroid_radius_df = centroids_df[['cluster', 'radius']].groupby('cluster').max().reset_index()


df_test = pd.merge(centroids_df_original,centroid_radius_df,how='left',on='cluster')
df_test.sort_values('cluster').head(10)
# Out:
#           long        lat                     nombre  \
# 99  -58.442423 -34.589049                   Fitz Roy
# 156 -58.445099 -34.592839                 Villarroel
# 125 -58.452927 -34.592212      Santos Dumont y Otero
# 102 -58.455062 -34.587548           Federico Lacroze
# 100 -58.445987 -34.586440                     Roseti
# 92  -58.449442 -34.591819                     Guzmin
# 187 -58.385586 -34.588475                    Posadas
# 164 -58.393317 -34.589150  Cementerio de la Recoleta
# 117 -58.397684 -34.588372               Emilio Mitre
# 113 -58.390786 -34.587812                   Quintana
#
#                                           domicilio  nro_est  \
# 99                           Fitz Roy 1092 y Loyola      101
# 156                           Villarroel y Humboldt      158
# 125                      Santos Dumont 4380 y Otero      127
# 102           Av Corrientes 6800 y Federico Lacroze      104
# 100                          Roseti 50 y Av Dorrego      102
# 92                                   Guzmin y Leiva       94
# 187  Posadas 1350 entre Montevideo y Rodriguez Pena      189
# 164        Vicente Lopez 2050 entre Junin y Uriburu      166
# 117   Plaza Emilio Mitre - Larrea y Pacheco de Melo      119
# 113                             Manuel Quintana 600      115
#
#                          dire_norm  capacidad  cluster  lat_centroide  \
# 99                   1092 FITZ ROY         12        0     -34.589985
# 156          VILLARROEL y HUMBOLDT         12        0     -34.589985
# 125             4380 DUMONT SANTOS         10        0     -34.589985
# 102             6900 CORRIENTES AV         20        0     -34.589985
# 100                      50 ROSETI         12        0     -34.589985
# 92                  GUZMaN y LEIVA         20        0     -34.589985
# 187                   1350 POSADAS         12        1     -34.588454
# 164             2050 LOPEZ VICENTE         12        1     -34.588454
# 117  LARREA y PACHECO DE MELO JOSE         12        1     -34.588454
# 113            600 QUINTANA MANUEL         10        1     -34.588454
#
#      long_centroide  geodesic_distance
# 99        -58.44849           0.660764
# 156       -58.44849           0.660764
# 125       -58.44849           0.660764
# 102       -58.44849           0.660764
# 100       -58.44849           0.660764
# 92        -58.44849           0.660764
# 187       -58.39319           0.697637
# 164       -58.39319           0.697637
# 117       -58.39319           0.697637
# 113       -58.39319           0.697637

# %%
centroid_radius_df = pd.merge(centroid_radius_df, centroids_df[['cluster', 'lat_centroide', 'long_centroide']]
                              , how='left', on='cluster').drop_duplicates()
centroid_radius_df.head()
# Out:
#     cluster  geodesic_distance  lat_centroide  long_centroide
# 0         0           0.660764     -34.589985      -58.448490
# 6         1           0.697637     -34.588454      -58.393190
# 14        2           0.759417     -34.613721      -58.377679
# 26        3           1.171162     -34.628008      -58.424064
# 35        4           0.709034     -34.603248      -58.416929

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, ax = plt.subplots(figsize=(10,10))

plt.scatter(centroids_df['lat'], centroids_df['long'] , s = 1, c = centroids_df['cluster'],
            cmap=plt.get_cmap('plasma'), label=centroids_df['cluster'])
plt.scatter(centroids_df['lat_centroide'], centroids_df['long_centroide'] , s = 10, c = 'blue', label = 'Centroides')

for cluster in centroid_radius_df.values.tolist():
    art = mpatches.Circle((cluster[2], cluster[3]),cluster[1]
                          , edgecolor='b',fill=False)
    ax.add_patch(art)
    
ax.axis('equal')
plt.legend()
plt.show()

# %%
for i in centroid_radius_df.values.tolist():
    print(i)
    break
# Out:
# [0.0, 0.007009361082007936, -34.5899847, -58.44848987]

# %%
newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
print(distance(newport_ri, cleveland_oh).miles)
# Out:
# 538.3904453677205
